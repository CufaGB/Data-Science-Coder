# %% [markdown]
# #Entrega 1
#
# *   Identificar 3 datasets que cumplan con las siguientes condiciones: a) al menos 2000 filas y b) al menos 15 columnas. Pueden buscar en las siguientes fuentes: GitLab, Github, Kaggle, Google Dataset Search (Si desean trabajar con un archivo propio se puede también)
#
# *   Algunas API recomendadas para obtener información: Marvel,PokeApi,CovidTracking,Nomics (Criptomonedas),Wheater API
#
# *   Cargar los archivos correspondientes por medio de la librería pandas
#
# *   Describir las variables potencialmente interesantes en cada archivo teniendo en cuenta el contexto comercial y analítico involucrado

# %% [markdown]
# ##Dataset 3: Dataset Resultados deportivos EPL 2016 a 2023
#
# ####En el último dataset tenemos los resultados deportivos entre los equipos participantes del torneo de fútbol de Inglaterra conocido como English Premier League (EPL) desde 2016 hasta 2023 (disputandose).
#
# ####Fuente: https://www.thesportsdb.com/api.php

# %% [markdown]
# ####Variables potenciales
#
# #####En este caso encontramos variables como:
#
#
#
# *   Goles de cada equipo.
# *   Partidos de cada equipo (Ganado, Empatado o Perdido)
# *   Elemento de lista
# *   Puntos obtenidos por temporada.
# *   Duelos contra otros equipos.
# *   Potencialmente determinar cual es la probabilidad del resultado.
# *   Estadisticas referidas al promedio de goles convertidos, recibidos.

# %%
#Importación de librería Pandas

import pandas as pd

#Permiso de acceso a drive y lectura de csv
from google.colab import drive
import os
drive.mount('/content/gdrive')


# %cd '/content/gdrive/MyDrive/DATA SCIENCE - CODER/Entregas/Entrega 1 - Datasets Potenciales/Premier League'
premier = pd.read_csv('premier_league.csv',sep=';')
print(premier.columns)
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/DATA SCIENCE - CODER/Entregas/Entrega 1 - Datasets Potenciales/Premier League
# Index(['id_partido', 'nombre_partido', 'partido_torneo', 'IdLiga', 'torneo',
#        'temporada', 'descripcion_partido', 'EquipoLocal', 'EquipoVisitante',
#        'GolLocal', 'fecha_torneo', 'GolVisitante', 'espectadores',
#        'fecha_hora_partido', 'fecha_partido', 'hora_partido',
#        'fecha_hora_partido.1', 'Id_EquipoLocal', 'Id_EquipoVisitante',
#        'estadio', 'pais', 'ciudad', 'poster_partido', 'imagen_partido',
#        'partido_fanart', 'partido_thumb', 'partido_banner', 'partido_video',
#        'estado_partido', 'partido_pospuesto'],
#       dtype='object')

# %%
premier.shape
# Out:
# (2544, 30)

# %%
premier
# Out:
#       id_partido                    nombre_partido  \
# 0         508731                 Hull vs Leicester
# 1         508732       Crystal Palace vs West Brom
# 2         508733              Everton vs Tottenham
# 3         508734            Middlesbrough vs Stoke
# 4         508735                Burnley vs Swansea
# ...          ...                               ...
# 2539     1570972  Manchester United vs Southampton
# 2540     1570973               Newcastle vs Wolves
# 2541     1570975           West Ham vs Aston Villa
# 2542     1570774          Southampton vs Brentford
# 2543     1570778        Brighton vs Crystal Palace
#
#                                          partido_torneo  IdLiga  \
# 0     English Premier League 2016-08-13 Hull vs Leic...    4328
# 1     English Premier League 2016-08-13 Crystal Pala...    4328
# 2     English Premier League 2016-08-13 Everton vs T...    4328
# 3     English Premier League 2016-08-13 Middlesbroug...    4328
# ...
