# %% [markdown]
# #Entrega 1
#
# *   Identificar 3 datasets que cumplan con las siguientes condiciones: a) al menos 2000 filas y b) al menos 15 columnas. Pueden buscar en las siguientes fuentes: GitLab, Github, Kaggle, Google Dataset Search (Si desean trabajar con un archivo propio se puede también)
#
# *   Algunas API recomendadas para obtener información: Marvel,PokeApi,CovidTracking,Nomics (Criptomonedas),Wheater API
#
# *   Cargar los archivos correspondientes por medio de la librería pandas
#
# *   Describir las variables potencialmente interesantes en cada archivo teniendo en cuenta el contexto comercial y analítico involucrado

# %% [markdown]
# ##Dataset 1: Airbnb Precios de 5 ciudades europeas
#
# ####En el siguiente Dataset se muestran los datos correspondientes a precios de 5 ciudades europeas, Amsterdam, Barceolna, Londres, Paris, Roma conforme algunos parametros como distancia al centro, al subte, cantidad de pasajeros, entre otros.
#
# ####Fuente: https://www.kaggle.com/datasets/thedevastator/airbnb-prices-in-european-cities

# %% [markdown]
# ####Variables potenciales
#
# #####En este caso encontramos variables como:
#
# *   Precio
# *   Ciudades (Amsterdam, Barcelona, Roma, Londres y Paris)
# *   Precio por ciudad, distancia al centro, al subte, cantidad de comensales, camas en cada Airbnb
# *   Promedio de Precios por ciudad
# *   Generar un "Airbnb patrón" dependiendo sus caracteristicas que le permita al cliente determinar el valor de su

# %%
#Importación de librería Pandas

import pandas as pd

#Permiso de acceso a drive y lectura de csv
from google.colab import drive
import os
drive.mount('/content/gdrive')

# %cd '/content/gdrive/MyDrive/DATA SCIENCE - CODER/Entregas/Entrega 1 - Datasets Potenciales/AirbnbEurope'
airbnb = pd.read_csv('airbnb_5europeancities.csv',sep=';')
print(airbnb.columns)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/DATA SCIENCE - CODER/Entregas/Entrega 1 - Datasets Potenciales/AirbnbEurope
# Index(['id_airbnb', 'realSum', 'room_type', 'room_shared', 'room_private',
#        'person_capacity', 'host_is_superhost', 'multi', 'biz',
#        'cleanliness_rating', 'guest_satisfaction_overall', 'bedrooms', 'dist',
#        'metro_dist', 'attr_index', 'attr_index_norm', 'rest_index',
#        'rest_index_norm', 'lng', 'lat', 'week', 'city'],
#       dtype='object')

# %%
airbnb.shape
# Out:
# (30621, 22)

# %%
airbnb
# Out:
#        id_airbnb     realSum     room_type  room_shared  room_private  \
# 0              0  194.033698  Private room        False          True
# 1              1  344.245776  Private room        False          True
# 2              2  264.101422  Private room        False          True
# 3              3  433.529398  Private room        False          True
# 4              4  485.552926  Private room        False          True
# ...          ...         ...           ...          ...           ...
# 30616      30616  327.460609  Private room        False          True
# 30617      30617  242.977169  Private room        False          True
# 30618      30618  138.943841  Private room        False          True
# 30619      30619  185.258454  Private room        False          True
# 30620      30620  254.614006  Private room        False          True
#
#        person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# ...
